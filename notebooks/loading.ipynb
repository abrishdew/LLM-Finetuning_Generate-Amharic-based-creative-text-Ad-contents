# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = '../data/cleaned/YeneTube (Cleaned and Labled) - YeneTube.csv'

# Load the CSV data into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Unnamed: 0 Unnamed: 1           Unnamed: 2  \
# 0         NaN         id                 date
# 1     21135.0      36761  2021-04-16 15:18:39
# 2     22658.0      38723  2021-08-18 12:09:48
# 3     23091.0      39289  2021-09-25 13:55:32
# 4     23553.0      39903  2021-11-14 12:33:29
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                               text     length   Category
# 1  በኢትዮጵያ 430 ሺህ ዜጎች የኮቪድ 19 ክትባት መከተባቸው የጤና ሚኒስቴ...        193     Non-Ad
# 2  ጠቅላይ ሚኒስትር አቢይ አሕመድ እና ልኡካን ቡድናቸው ለሥራ ጉብኝት ቱርክ...        193     Non-Ad
# 3  አቶ ሽመልስ አብዲሳ የኦሮሚያ ክልል ፕሬዚዳንት ሆነው ተመረጡ! የጨፌ ኦሮ...        193     Non-Ad
# 4  የአዲስ አበባ ከተማ ከንቲባ አዳነች አቤቤ ለሰራዊቱና ለተፈናቀሉ ወገኖች ...        193     Non-Ad
#
#   Unnamed: 6  Unnamed: 7  Total Ads  Total NonAds  ... Financial services  \
# 0        Tag       False      635.0       28571.0  ...               15.0
# 1        NaN        True        NaN           NaN  ...                NaN
# ...

# %%
df
# Out:
#        Unnamed: 0 Unnamed: 1           Unnamed: 2  \
# 0             NaN         id                 date
# 1         21135.0      36761  2021-04-16 15:18:39
# 2         22658.0      38723  2021-08-18 12:09:48
# 3         23091.0      39289  2021-09-25 13:55:32
# 4         23553.0      39903  2021-11-14 12:33:29
# ...           ...        ...                  ...
# 29202       905.0       3870  2018-06-02 22:19:27
# 29203      5494.0      13539  2019-01-04 10:30:06
# 29204     27199.0      45375  2023-02-09 19:11:10
# 29205      6409.0      15647  2019-02-26 19:36:16
# 29206     27404.0      45770  2023-03-17 19:22:12
#
#                                               Unnamed: 3 Unnamed: 4  \
# 0                                                   text     length
# 1      በኢትዮጵያ 430 ሺህ ዜጎች የኮቪድ 19 ክትባት መከተባቸው የጤና ሚኒስቴ...        193
# 2      ጠቅላይ ሚኒስትር አቢይ አሕመድ እና ልኡካን ቡድናቸው ለሥራ ጉብኝት ቱርክ...        193
# 3      አቶ ሽመልስ አብዲሳ የኦሮሚያ ክልል ፕሬዚዳንት ሆነው ተመረጡ! የጨፌ ኦሮ...        193
# ...

# %%
df
# Out:
#        Unnamed: 0 Unnamed: 1           Unnamed: 2  \
# 0             NaN         id                 date
# 1         21135.0      36761  2021-04-16 15:18:39
# 2         22658.0      38723  2021-08-18 12:09:48
# 3         23091.0      39289  2021-09-25 13:55:32
# 4         23553.0      39903  2021-11-14 12:33:29
# ...           ...        ...                  ...
# 29202       905.0       3870  2018-06-02 22:19:27
# 29203      5494.0      13539  2019-01-04 10:30:06
# 29204     27199.0      45375  2023-02-09 19:11:10
# 29205      6409.0      15647  2019-02-26 19:36:16
# 29206     27404.0      45770  2023-03-17 19:22:12
#
#                                               Unnamed: 3 Unnamed: 4  \
# 0                                                   text     length
# 1      በኢትዮጵያ 430 ሺህ ዜጎች የኮቪድ 19 ክትባት መከተባቸው የጤና ሚኒስቴ...        193
# 2      ጠቅላይ ሚኒስትር አቢይ አሕመድ እና ልኡካን ቡድናቸው ለሥራ ጉብኝት ቱርክ...        193
# 3      አቶ ሽመልስ አብዲሳ የኦሮሚያ ክልል ፕሬዚዳንት ሆነው ተመረጡ! የጨፌ ኦሮ...        193
# ...

# %%
df
# Out:
#        Unnamed: 0 Unnamed: 1           Unnamed: 2  \
# 0             NaN         id                 date
# 1         21135.0      36761  2021-04-16 15:18:39
# 2         22658.0      38723  2021-08-18 12:09:48
# 3         23091.0      39289  2021-09-25 13:55:32
# 4         23553.0      39903  2021-11-14 12:33:29
# ...           ...        ...                  ...
# 29202       905.0       3870  2018-06-02 22:19:27
# 29203      5494.0      13539  2019-01-04 10:30:06
# 29204     27199.0      45375  2023-02-09 19:11:10
# 29205      6409.0      15647  2019-02-26 19:36:16
# 29206     27404.0      45770  2023-03-17 19:22:12
#
#                                               Unnamed: 3 Unnamed: 4  \
# 0                                                   text     length
# 1      በኢትዮጵያ 430 ሺህ ዜጎች የኮቪድ 19 ክትባት መከተባቸው የጤና ሚኒስቴ...        193
# 2      ጠቅላይ ሚኒስትር አቢይ አሕመድ እና ልኡካን ቡድናቸው ለሥራ ጉብኝት ቱርክ...        193
# 3      አቶ ሽመልስ አብዲሳ የኦሮሚያ ክልል ፕሬዚዳንት ሆነው ተመረጡ! የጨፌ ኦሮ...        193
# ...

# %%
filtered_df = df[['Unnamed: 3', 'Unnamed: 5']]
print(filtered_df.head())
# Out:
#                                           Unnamed: 3 Unnamed: 5
# 0                                               text   Category
# 1  በኢትዮጵያ 430 ሺህ ዜጎች የኮቪድ 19 ክትባት መከተባቸው የጤና ሚኒስቴ...     Non-Ad
# 2  ጠቅላይ ሚኒስትር አቢይ አሕመድ እና ልኡካን ቡድናቸው ለሥራ ጉብኝት ቱርክ...     Non-Ad
# 3  አቶ ሽመልስ አብዲሳ የኦሮሚያ ክልል ፕሬዚዳንት ሆነው ተመረጡ! የጨፌ ኦሮ...     Non-Ad
# 4  የአዲስ አበባ ከተማ ከንቲባ አዳነች አቤቤ ለሰራዊቱና ለተፈናቀሉ ወገኖች ...     Non-Ad

# %%
non_ads_df = filtered_df[filtered_df['Unnamed: 5'] != 'Non-Ad']
print(non_ads_df.head())
# Out:
#                                             Unnamed: 3     Unnamed: 5
# 0                                                 text       Category
# 40   ወደ ሀዋሳ እና ዝዋይ / ባቱ ለአመታዊ የቅዱስ ገብርኤል ክብረ በኣል ተጓ...         Travel
# 72   የዛሬ ጨዋታዎች የቤትስኬት ግምት ማሊ፣ ስፔን፣ ፖርቹጋልን እና ሌቫንቴን ...  Entertainment
# 109  ️ SHOPIA ️ በአስገራሚ ዋጋ ብቅ ብሏል️ ቱታዎች // ሱሪዎች // ጃ...         Retail
# 116  ዌብሳይት ለማሰራት ካሰቡ ትክክለኛው ቦታ ላይ ኖት! ፍጥነት የማይሞላ ገራ...          Other

# %%
non_ads_df
# Out:
#                                               Unnamed: 3     Unnamed: 5
# 0                                                   text       Category
# 40     ወደ ሀዋሳ እና ዝዋይ / ባቱ ለአመታዊ የቅዱስ ገብርኤል ክብረ በኣል ተጓ...         Travel
# 72     የዛሬ ጨዋታዎች የቤትስኬት ግምት ማሊ፣ ስፔን፣ ፖርቹጋልን እና ሌቫንቴን ...  Entertainment
# 109    ️ SHOPIA ️ በአስገራሚ ዋጋ ብቅ ብሏል️ ቱታዎች // ሱሪዎች // ጃ...         Retail
# 116    ዌብሳይት ለማሰራት ካሰቡ ትክክለኛው ቦታ ላይ ኖት! ፍጥነት የማይሞላ ገራ...          Other
# ...                                                  ...            ...
# 27671  ማስታወቂያ/ጥቆማ‼️ የአዲስ አበባ ዩኒቨርስቲ ለ2012 ኣም የትምህርት ዘ...          Other
# 28447  AWS mining international በሀገራችን ከገባ የወራት እድሜ ያ...          Other
# 28742  ማር እስከ ጧፍ (ፍቅር እስከ መቃብር) በድምፃዊ ቴዎድሮስ ካሳሁን (ቴዲ ...          Media
# 28893  ⬆️ከኢሳት የስራ አስፈፃሚ ቦርድ የተሰጠ መግለጫ! ጉዳዩ የኢሳትን መዋቅና...          Media
# 29077  Fiker: for more lyrics ቴዎድሮስ! በድምፃዊ ቴዎድሮስ ካሳሁን...          Media
#
# [636 rows x 2 columns]

# %%
unnamed_3_column = non_ads_df['Unnamed: 3']
print(unnamed_3_column)
# Out:
# 0                                                     text
# 40       ወደ ሀዋሳ እና ዝዋይ / ባቱ ለአመታዊ የቅዱስ ገብርኤል ክብረ በኣል ተጓ...
# 72       የዛሬ ጨዋታዎች የቤትስኬት ግምት ማሊ፣ ስፔን፣ ፖርቹጋልን እና ሌቫንቴን ...
# 109      ️ SHOPIA ️ በአስገራሚ ዋጋ ብቅ ብሏል️ ቱታዎች // ሱሪዎች // ጃ...
# 116      ዌብሳይት ለማሰራት ካሰቡ ትክክለኛው ቦታ ላይ ኖት! ፍጥነት የማይሞላ ገራ...
#                                ...
# 27671    ማስታወቂያ/ጥቆማ‼️ የአዲስ አበባ ዩኒቨርስቲ ለ2012 ኣም የትምህርት ዘ...
# 28447    AWS mining international በሀገራችን ከገባ የወራት እድሜ ያ...
# 28742    ማር እስከ ጧፍ (ፍቅር እስከ መቃብር) በድምፃዊ ቴዎድሮስ ካሳሁን (ቴዲ ...
# 28893    ⬆️ከኢሳት የስራ አስፈፃሚ ቦርድ የተሰጠ መግለጫ! ጉዳዩ የኢሳትን መዋቅና...
# 29077    Fiker: for more lyrics ቴዎድሮስ! በድምፃዊ ቴዎድሮስ ካሳሁን...
# Name: Unnamed: 3, Length: 636, dtype: object

# %%
# Save the unnamed_3_column to a text file
unnamed_3_column.to_csv('labled.txt', index=False, header=True)

print("The data has been saved to 'unnamed_3_column.txt'.")
# Out:
# The data has been saved to 'unnamed_3_column.txt'.
